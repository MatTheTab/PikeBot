# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_comparison(stockfish_result_path, engine_result_path):
    stockfish_lengths = np.loadtxt(stockfish_result_path, delimiter=';')
    engine_lengths = np.loadtxt(engine_result_path, delimiter=";")

    cumulative_stockfish = np.cumsum(stockfish_lengths[1])
    cumulative_engine = np.cumsum(engine_lengths[1])


    plt.plot(stockfish_lengths[0], cumulative_stockfish, label="stockfish")
    plt.plot(engine_lengths[0], cumulative_engine, label="Pikebot")

    plt.title('Cumulative Analysis of Stockfish and Pikebot Lengths')
    plt.xlabel('Length')
    plt.ylabel('Cumulative number of ended games')

    plt.legend()

    plt.show()

# %%
stockfish_result_path = "results\MaiaChess_OptimalSimpleEngineAgent_silversuite_Sat_Nov_16_12-20-20_2024\statistics\MaiaChess_OptimalSimpleEngineAgent_game_lengths.csv"
engine_result_path = "results\MaiaChess_PikeBotHeuristic9_silversuite_Fri_Jan__3_00-51-54_2025\statistics\MaiaChess_PikeBotHeuristic9_game_lengths.csv"
plot_comparison(stockfish_result_path, engine_result_path)

# %%
stockfish_result_path = "results\MaiaChess_OptimalSimpleEngineAgent_silversuite_Sat_Nov_16_12-20-20_2024\statistics\OptimalSimpleEngineAgent_MaiaChess_game_lengths.csv"
engine_result_path = "results\MaiaChess_PikeBotHeuristic9_silversuite_Fri_Jan__3_00-51-54_2025\statistics\PikeBotHeuristic9_MaiaChess_game_lengths.csv"

plot_comparison(stockfish_result_path, engine_result_path)
